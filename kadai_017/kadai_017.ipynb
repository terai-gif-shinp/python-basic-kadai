# %% [markdown]
# ●課題
# 学習したことを組み合わせてコードを書こう
#
# 課題の内容
# 名前(name)と年齢(age)の属性を持つHumanクラスを作成してください。
#
# Humanクラスには、以下の条件で標準出力(print)するcheck_adultメソッドを追加してください。
#
# ageが20以上の場合に大人であること
# そうでない場合に大人でないこと
# Humanクラスのインスタンスを複数生成してリストに追加し、リストの要素数分だけcheck_adultメソッドを呼び出してください。
#
#
# 合格基準
# - 本教材で学習した「リスト・ディクショナリ」「条件分岐」「繰り返し処理」
# - 「関数」「変数のスコープ」「クラス」を用いて、
# - 「課題の内容」の仕様通りのプログラムが記述されている

# %%
class Human:
    def __init__(self, name, age):
        # 属性を定義
        self.name = name
        self.age = age

    # メソッドを定義
    def check_adult(self):
        if self.age >= 20:
            print(f"{self.name}は大人です。")

        else:
            print(f"{self.name}は大人ではありません。")

# 連想配列を定義
personal_date = {"tanaka":18, "sato":25, "terai": 32, "yasuda":14}

# インスタンスを格納するリストを定義
human_list = []

# 繰り返し処理（インスタンス化、nameとageに代入していく？）
for name, age in personal_date.items():
    # Humanクラスのインスタンスを作成し、リストに追加
    person = Human(name, age)
    human_list.append(person)



# リストの要素数分だけメソッドを呼び出す
for person in human_list:
    person.check_adult()
# Out:
# tanakaは大人ではありません。
# satoは大人です。
# teraiは大人です。
# yasudaは大人ではありません。
